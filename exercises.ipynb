# %% [markdown]
# <font color='darkred'> Unless otherwise noted, **this notebook will not be reviewed or autograded.**</font> You are welcome to use it for scratchwork, but **only the files listed in the exercises will be checked.**
#
# ---
#
# # Exercises
#
# For these exercises, you'll be creating a [Python class](https://www.hackerearth.com/practice/python/object-oriented-programming/classes-and-objects-i/tutorial/) in the *apputil.py* file.
#
# A few tips:
#
# - Some of these exercises will require some "JSON digging".
# - <font color='lightblue'>Your functions should still adhere to [best practices](https://codesignal.com/learn/courses/clean-code-basics-with-python/lessons/clean-function-design-in-python), so **your class should probably contain more functions than only the ones dictated below**.</font>

# %% [markdown]
# ## Exercise 1
#
# Create a Python class named `Genius` such that the following code initializes the object, and "saves" the access token as an attribute of the object. You'll need to use this attribute for Exercises 2 and 3.
#
# ```python
# from apputil import Genius
#
# genius = Genius(access_token="access_token")
# ```

# %%
# %load_ext autoreload

# %%
import importlib
import apputil

importlib.reload(apputil)

from apputil import Genius
import importlib
importlib.reload(apputil)

genius = Genius(access_token="vw58dWIGES4DS1hb7pYPdbSyEIR_klztMKLcOgK3HtH2qFCn9EESV5p7xs96IiQc")
print(genius.get_access_token())
genius.get_artist("Radiohead")

genius.get_artists("Radiohead", "Coldplay", "Adele")
# Out:
# vw58dWIGES4DS1hb7pYPdbSyEIR_klztMKLcOgK3HtH2qFCn9EESV5p7xs96IiQc
# [{'highlights': [],
#   'index': 'song',
#   'type': 'song',
#   'result': {'annotation_count': 8,
#    'api_path': '/songs/109096',
#    'artist_names': 'Radiohead',
#    'full_title': 'Creep by\xa0Radiohead',
#    'header_image_thumbnail_url': 'https://images.genius.com/11b15d6660e051703a5b2b10af2e7a56.300x300x1.png',
#    'header_image_url': 'https://images.genius.com/11b15d6660e051703a5b2b10af2e7a56.1000x1000x1.png',
#    'id': 109096,
#    'lyrics_owner_id': 116340,
#    'lyrics_state': 'complete',
#    'path': '/Radiohead-creep-lyrics',
#    'primary_artist_names': 'Radiohead',
#    'pyongs_count': 297,
#    'relationships_index_url': 'https://genius.com/Radiohead-creep-sample',
#    'release_date_components': {'year': 1992, 'month': 9, 'day': 21},
#    'release_date_for_display': 'September 21, 1992',
#    'release_date_with_abbreviated_month_for_display': 'Sep. 21, 1992',
#    'song_art_image_thumbnail_url': 'https://images.genius.com/11b15d6660e051703a5b2b10af2e7a56.300x300x1.png',
#    'song_art_image_url': 'https://images.genius.com/11b15d6660e051703a5b2b10af2e7a56.1000x1000x1.png',
#    'stats': {'unreviewed_annotations': 1,
#     'concurrents': 59,
#     'hot': True,
#     'pageviews': 8451193},
#    'title': 'Creep',
#    'title_with_featured': 'Creep',
#    'url': 'https://genius.com/Radiohead-creep-lyrics',
#    'featured_artists': [],
#    'primary_artist': {'api_path': '/artists/604',
#     'header_image_url': 'https://images.genius.com/808140e9f02c9da6401c0bbb2329a5af.1000x165x1.png',
#     'id': 604,
#     'image_url': 'https://images.genius.com/2642340aee5282c5824397692a49a76a.1000x1000x1.jpg',
#     'is_meme_verified': False,
#     'is_verified': False,
#     'name': 'Radiohead',
#     'url': 'https://genius.com/artists/Radiohead'},
#    'primary_artists': [{'api_path': '/artists/604',
#      'header_image_url': 'https://images.genius.com/808140e9f02c9da6401c0bbb2329a5af.1000x165x1.png',
#      'id': 604,
#      'image_url': 'https://images.genius.com/2642340aee5282c5824397692a49a76a.1000x1000x1.jpg',
#      'is_meme_verified': False,
#      'is_verified': False,
#      'name': 'Radiohead',
#      'url': 'https://genius.com/artists/Radiohead'}]}},
#  {'highlights': [],
#   'index': 'song',
#   'type': 'song',
#   'result': {'annotation_count': 10,
#    'api_path': '/songs/64344',
#    'artist_names': 'Radiohead',
#    'full_title': 'Karma Police by\xa0Radiohead',
#    'header_image_thumbnail_url': 'https://images.genius.com/57f9b08c6516f1221a6fbf9f194ad285.300x300x1.png',
#    'header_image_url': 'https://images.genius.com/57f9b08c6516f1221a6fbf9f194ad285.1000x1000x1.png',
#    'id': 64344,
#    'lyrics_owner_id': 66760,
#    'lyrics_state': 'complete',
#    'path': '/Radiohead-karma-police-lyrics',
#    'primary_artist_names': 'Radiohead',
#    'pyongs_count': 110,
#    'relationships_index_url': 'https://genius.com/Radiohead-karma-police-sample',
#    'release_date_components': {'year': 1997, 'month': 5, 'day': 21},
#    'release_date_for_display': 'May 21, 1997',
#    'release_date_with_abbreviated_month_for_display': 'May 21, 1997',
#    'song_art_image_thumbnail_url': 'https://images.genius.com/57f9b08c6516f1221a6fbf9f194ad285.300x300x1.png',
#    'song_art_image_url': 'https://images.genius.com/57f9b08c6516f1221a6fbf9f194ad285.1000x1000x1.png',
#    'stats': {'unreviewed_annotations': 1,
#     'concurrents': 2,
#     'hot': False,
#     'pageviews': 2052720},
#    'title': 'Karma Police',
#    'title_with_featured': 'Karma Police',
#    'url': 'https://genius.com/Radiohead-karma-police-lyrics',
#    'featured_artists': [],
#    'primary_artist': {'api_path': '/artists/604',
#     'header_image_url': 'https://images.genius.com/808140e9f02c9da6401c0bbb2329a5af.1000x165x1.png',
#     'id': 604,
#     'image_url': 'https://images.genius.com/2642340aee5282c5824397692a49a76a.1000x1000x1.jpg',
#     'is_meme_verified': False,
#     'is_verified': False,
#     'name': 'Radiohead',
#     'url': 'https://genius.com/artists/Radiohead'},
#    'primary_artists': [{'api_path': '/artists/604',
#      'header_image_url': 'https://images.genius.com/808140e9f02c9da6401c0bbb2329a5af.1000x165x1.png',
#      'id': 604,
#      'image_url': 'https://images.genius.com/2642340aee5282c5824397692a49a76a.1000x1000x1.jpg',
#      'is_meme_verified': False,
#      'is_verified': False,
#      'name': 'Radiohead',
#      'url': 'https://genius.com/artists/Radiohead'}]}},
#  {'highlights': [],
#   'index': 'song',
#   'type': 'song',
#   'result': {'annotation_count': 11,
#    'api_path': '/songs/71498',
#    'artist_names': 'Radiohead',
#    'full_title': 'No Surprises by\xa0Radiohead',
#    'header_image_thumbnail_url': 'https://images.genius.com/830478b3c330cd4763163b9b52d89ac7.300x300x1.png',
#    'header_image_url': 'https://images.genius.com/830478b3c330cd4763163b9b52d89ac7.1000x1000x1.png',
#    'id': 71498,
#    'lyrics_owner_id': 94134,
#    'lyrics_state': 'complete',
#    'path': '/Radiohead-no-surprises-lyrics',
#    'primary_artist_names': 'Radiohead',
#    'pyongs_count': 121,
#    'relationships_index_url': 'https://genius.com/Radiohead-no-surprises-sample',
#    'release_date_components': {'year': 1997, 'month': 5, 'day': 21},
#    'release_date_for_display': 'May 21, 1997',
#    'release_date_with_abbreviated_month_for_display': 'May 21, 1997',
#    'song_art_image_thumbnail_url': 'https://images.genius.com/830478b3c330cd4763163b9b52d89ac7.300x300x1.png',
#    'song_art_image_url': 'https://images.genius.com/830478b3c330cd4763163b9b52d89ac7.1000x1000x1.png',
#    'stats': {'unreviewed_annotations': 1, 'hot': False, 'pageviews': 1393010},
#    'title': 'No Surprises',
#    'title_with_featured': 'No Surprises',
#    'url': 'https://genius.com/Radiohead-no-surprises-lyrics',
#    'featured_artists': [],
#    'primary_artist': {'api_path': '/artists/604',
#     'header_image_url': 'https://images.genius.com/808140e9f02c9da6401c0bbb2329a5af.1000x165x1.png',
#     'id': 604,
#     'image_url': 'https://images.genius.com/2642340aee5282c5824397692a49a76a.1000x1000x1.jpg',
#     'is_meme_verified': False,
#     'is_verified': False,
#     'name': 'Radiohead',
#     'url': 'https://genius.com/artists/Radiohead'},
#    'primary_artists': [{'api_path': '/artists/604',
#      'header_image_url': 'https://images.genius.com/808140e9f02c9da6401c0bbb2329a5af.1000x165x1.png',
#      'id': 604,
#      'image_url': 'https://images.genius.com/2642340aee5282c5824397692a49a76a.1000x1000x1.jpg',
#      'is_meme_verified': False,
#      'is_verified': False,
#      'name': 'Radiohead',
#      'url': 'https://genius.com/artists/Radiohead'}]}},
#  {'highlights': [],
#   'index': 'song',
#   'type': 'song',
#   'result': {'annotation_count': 13,
#    'api_path': '/songs/107387',
#    'artist_names': 'Radiohead',
#    'full_title': 'Exit Music (For A Film) by\xa0Radiohead',
#    'header_image_thumbnail_url': 'https://images.genius.com/9546e3ab083649dbae5ab68070b748af.300x300x1.png',
#    'header_image_url': 'https://images.genius.com/9546e3ab083649dbae5ab68070b748af.1000x1000x1.png',
#    'id': 107387,
#    'lyrics_owner_id': 168499,
#    'lyrics_state': 'complete',
#    'path': '/Radiohead-exit-music-for-a-film-lyrics',
#    'primary_artist_names': 'Radiohead',
#    'pyongs_count': 94,
#    'relationships_index_url': 'https://genius.com/Radiohead-exit-music-for-a-film-sample',
#    'release_date_components': {'year': 1997, 'month': 5, 'day': 21},
#    'release_date_for_display': 'May 21, 1997',
#    'release_date_with_abbreviated_month_for_display': 'May 21, 1997',
#    'song_art_image_thumbnail_url': 'https://images.genius.com/9546e3ab083649dbae5ab68070b748af.300x300x1.png',
#    'song_art_image_url': 'https://images.genius.com/9546e3ab083649dbae5ab68070b748af.1000x1000x1.png',
#    'stats': {'unreviewed_annotations': 0,
#     'concurrents': 2,
#     'hot': False,
#     'pageviews': 1086772},
#    'title': 'Exit Music (For A Film)',
#    'title_with_featured': 'Exit Music (For A Film)',
#    'url': 'https://genius.com/Radiohead-exit-music-for-a-film-lyrics',
#    'featured_artists': [],
#    'primary_artist': {'api_path': '/artists/604',
#     'header_image_url': 'https://images.genius.com/808140e9f02c9da6401c0bbb2329a5af.1000x165x1.png',
#     'id': 604,
#     'image_url': 'https://images.genius.com/2642340aee5282c5824397692a49a76a.1000x1000x1.jpg',
#     'is_meme_verified': False,
#     'is_verified': False,
#     'name': 'Radiohead',
#     'url': 'https://genius.com/artists/Radiohead'},
#    'primary_artists': [{'api_path': '/artists/604',
#      'header_image_url': 'https://images.genius.com/808140e9f02c9da6401c0bbb2329a5af.1000x165x1.png',
#      'id': 604,
#      'image_url': 'https://images.genius.com/2642340aee5282c5824397692a49a76a.1000x1000x1.jpg',
#      'is_meme_verified': False,
#      'is_verified': False,
#      'name': 'Radiohead',
#      'url': 'https://genius.com/artists/Radiohead'}]}},
#  {'highlights': [],
#   'index': 'song',
#   'type': 'song',
#   'result': {'annotation_count': 11,
#    'api_path': '/songs/1188',
#    'artist_names': 'Radiohead',
#    'full_title': 'Fake Plastic Trees by\xa0Radiohead',
#    'header_image_thumbnail_url': 'https://images.genius.com/0a920bfb1109876ab7b5bd8dfb47b1f7.300x300x1.jpg',
#    'header_image_url': 'https://images.genius.com/0a920bfb1109876ab7b5bd8dfb47b1f7.1000x1000x1.jpg',
#    'id': 1188,
#    'lyrics_owner_id': 7,
#    'lyrics_state': 'complete',
#    'path': '/Radiohead-fake-plastic-trees-lyrics',
#    'primary_artist_names': 'Radiohead',
#    'pyongs_count': 99,
#    'relationships_index_url': 'https://genius.com/Radiohead-fake-plastic-trees-sample',
#    'release_date_components': {'year': 1995, 'month': 3, 'day': 13},
#    'release_date_for_display': 'March 13, 1995',
#    'release_date_with_abbreviated_month_for_display': 'Mar. 13, 1995',
#    'song_art_image_thumbnail_url': 'https://images.genius.com/0a920bfb1109876ab7b5bd8dfb47b1f7.300x300x1.jpg',
#    'song_art_image_url': 'https://images.genius.com/0a920bfb1109876ab7b5bd8dfb47b1f7.1000x1000x1.jpg',
#    'stats': {'unreviewed_annotations': 0, 'hot': False, 'pageviews': 852675},
#    'title': 'Fake Plastic Trees',
#    'title_with_featured': 'Fake Plastic Trees',
#    'url': 'https://genius.com/Radiohead-fake-plastic-trees-lyrics',
#    'featured_artists': [],
#    'primary_artist': {'api_path': '/artists/604',
#     'header_image_url': 'https://images.genius.com/808140e9f02c9da6401c0bbb2329a5af.1000x165x1.png',
#     'id': 604,
#     'image_url': 'https://images.genius.com/2642340aee5282c5824397692a49a76a.1000x1000x1.jpg',
#     'is_meme_verified': False,
#     'is_verified': False,
#     'name': 'Radiohead',
#     'url': 'https://genius.com/artists/Radiohead'},
#    'primary_artists': [{'api_path': '/artists/604',
#      'header_image_url': 'https://images.genius.com/808140e9f02c9da6401c0bbb2329a5af.1000x165x1.png',
#      'id': 604,
#      'image_url': 'https://images.genius.com/2642340aee5282c5824397692a49a76a.1000x1000x1.jpg',
#      'is_meme_verified': False,
#      'is_verified': False,
#      'name': 'Radiohead',
#      'url': 'https://genius.com/artists/Radiohead'}]}},
#  {'highlights': [],
#   'index': 'song',
#   'type': 'song',
#   'result': {'annotation_count': 10,
#    'api_path': '/songs/78831',
#    'artist_names': 'Radiohead',
#    'full_title': 'Paranoid Android by\xa0Radiohead',
#    'header_image_thumbnail_url': 'https://images.genius.com/252580f10c55f58d073b5f54e453c17d.300x300x1.png',
#    'header_image_url': 'https://images.genius.com/252580f10c55f58d073b5f54e453c17d.1000x1000x1.png',
#    'id': 78831,
#    'lyrics_owner_id': 1850,
#    'lyrics_state': 'complete',
#    'path': '/Radiohead-paranoid-android-lyrics',
#    'primary_artist_names': 'Radiohead',
#    'pyongs_count': 119,
#    'relationships_index_url': 'https://genius.com/Radiohead-paranoid-android-sample',
#    'release_date_components': {'year': 1997, 'month': 5, 'day': 21},
#    'release_date_for_display': 'May 21, 1997',
#    'release_date_with_abbreviated_month_for_display': 'May 21, 1997',
#    'song_art_image_thumbnail_url': 'https://images.genius.com/252580f10c55f58d073b5f54e453c17d.300x300x1.png',
#    'song_art_image_url': 'https://images.genius.com/252580f10c55f58d073b5f54e453c17d.1000x1000x1.png',
#    'stats': {'unreviewed_annotations': 1,
#     'concurrents': 2,
#     'hot': False,
#     'pageviews': 848840},
#    'title': 'Paranoid Android',
#    'title_with_featured': 'Paranoid Android',
#    'url': 'https://genius.com/Radiohead-paranoid-android-lyrics',
#    'featured_artists': [],
#    'primary_artist': {'api_path': '/artists/604',
#     'header_image_url': 'https://images.genius.com/808140e9f02c9da6401c0bbb2329a5af.1000x165x1.png',
#     'id': 604,
#     'image_url': 'https://images.genius.com/2642340aee5282c5824397692a49a76a.1000x1000x1.jpg',
#     'is_meme_verified': False,
#     'is_verified': False,
#     'name': 'Radiohead',
#     'url': 'https://genius.com/artists/Radiohead'},
#    'primary_artists': [{'api_path': '/artists/604',
#      'header_image_url': 'https://images.genius.com/808140e9f02c9da6401c0bbb2329a5af.1000x165x1.png',
#      'id': 604,
#      'image_url': 'https://images.genius.com/2642340aee5282c5824397692a49a76a.1000x1000x1.jpg',
#      'is_meme_verified': False,
#      'is_verified': False,
#      'name': 'Radiohead',
#      'url': 'https://genius.com/artists/Radiohead'}]}},
#  {'highlights': [],
#   'index': 'song',
#   'type': 'song',
#   'result': {'annotation_count': 11,
#    'api_path': '/songs/78354',
#    'artist_names': 'Radiohead',
#    'full_title': 'Let Down by\xa0Radiohead',
#    'header_image_thumbnail_url': 'https://images.genius.com/f018ac47288c247bf5e855a660e59974.300x268x1.jpg',
#    'header_image_url': 'https://images.genius.com/f018ac47288c247bf5e855a660e59974.600x535x1.jpg',
#    'id': 78354,
#    'lyrics_owner_id': 46705,
#    'lyrics_state': 'complete',
#    'path': '/Radiohead-let-down-lyrics',
#    'primary_artist_names': 'Radiohead',
#    'pyongs_count': 81,
#    'relationships_index_url': 'https://genius.com/Radiohead-let-down-sample',
#    'release_date_components': {'year': 1997, 'month': 5, 'day': 21},
#    'release_date_for_display': 'May 21, 1997',
#    'release_date_with_abbreviated_month_for_display': 'May 21, 1997',
#    'song_art_image_thumbnail_url': 'https://images.genius.com/f018ac47288c247bf5e855a660e59974.300x268x1.jpg',
#    'song_art_image_url': 'https://images.genius.com/f018ac47288c247bf5e855a660e59974.600x535x1.jpg',
#    'stats': {'unreviewed_annotations': 3,
#     'concurrents': 4,
#     'hot': False,
#     'pageviews': 863491},
#    'title': 'Let Down',
#    'title_with_featured': 'Let Down',
#    'url': 'https://genius.com/Radiohead-let-down-lyrics',
#    'featured_artists': [],
#    'primary_artist': {'api_path': '/artists/604',
#     'header_image_url': 'https://images.genius.com/808140e9f02c9da6401c0bbb2329a5af.1000x165x1.png',
#     'id': 604,
#     'image_url': 'https://images.genius.com/2642340aee5282c5824397692a49a76a.1000x1000x1.jpg',
#     'is_meme_verified': False,
#     'is_verified': False,
#     'name': 'Radiohead',
#     'url': 'https://genius.com/artists/Radiohead'},
#    'primary_artists': [{'api_path': '/artists/604',
#      'header_image_url': 'https://images.genius.com/808140e9f02c9da6401c0bbb2329a5af.1000x165x1.png',
#      'id': 604,
#      'image_url': 'https://images.genius.com/2642340aee5282c5824397692a49a76a.1000x1000x1.jpg',
#      'is_meme_verified': False,
#      'is_verified': False,
#      'name': 'Radiohead',
#      'url': 'https://genius.com/artists/Radiohead'}]}},
#  {'highlights': [],
#   'index': 'song',
#   'type': 'song',
#   'result': {'annotation_count': 10,
#    'api_path': '/songs/65925',
#    'artist_names': 'Radiohead',
#    'full_title': 'All I Need by\xa0Radiohead',
#    'header_image_thumbnail_url': 'https://images.genius.com/d0bda7df3e09e0a4d22b671e081a1c46.300x300x1.png',
#    'header_image_url': 'https://images.genius.com/d0bda7df3e09e0a4d22b671e081a1c46.1000x1000x1.png',
#    'id': 65925,
#    'lyrics_owner_id': 11637,
#    'lyrics_state': 'complete',
#    'path': '/Radiohead-all-i-need-lyrics',
#    'primary_artist_names': 'Radiohead',
#    'pyongs_count': 56,
#    'relationships_index_url': 'https://genius.com/Radiohead-all-i-need-sample',
#    'release_date_components': {'year': 2007, 'month': 10, 'day': 10},
#    'release_date_for_display': 'October 10, 2007',
#    'release_date_with_abbreviated_month_for_display': 'Oct. 10, 2007',
#    'song_art_image_thumbnail_url': 'https://images.genius.com/d0bda7df3e09e0a4d22b671e081a1c46.300x300x1.png',
#    'song_art_image_url': 'https://images.genius.com/d0bda7df3e09e0a4d22b671e081a1c46.1000x1000x1.png',
#    'stats': {'unreviewed_annotations': 2, 'hot': False, 'pageviews': 605486},
#    'title': 'All I Need',
#    'title_with_featured': 'All I Need',
#    'url': 'https://genius.com/Radiohead-all-i-need-lyrics',
#    'featured_artists': [],
#    'primary_artist': {'api_path': '/artists/604',
#     'header_image_url': 'https://images.genius.com/808140e9f02c9da6401c0bbb2329a5af.1000x165x1.png',
#     'id': 604,
#     'image_url': 'https://images.genius.com/2642340aee5282c5824397692a49a76a.1000x1000x1.jpg',
#     'is_meme_verified': False,
#     'is_verified': False,
#     'name': 'Radiohead',
#     'url': 'https://genius.com/artists/Radiohead'},
#    'primary_artists': [{'api_path': '/artists/604',
#      'header_image_url': 'https://images.genius.com/808140e9f02c9da6401c0bbb2329a5af.1000x165x1.png',
#      'id': 604,
#      'image_url': 'https://images.genius.com/2642340aee5282c5824397692a49a76a.1000x1000x1.jpg',
#      'is_meme_verified': False,
#      'is_verified': False,
#      'name': 'Radiohead',
#      'url': 'https://genius.com/artists/Radiohead'}]}},
#  {'highlights': [],
#   'index': 'song',
#   'type': 'song',
#   'result': {'annotation_count': 7,
#    'api_path': '/songs/67774',
#    'artist_names': 'Radiohead',
#    'full_title': 'How to Disappear Completely by\xa0Radiohead',
#    'header_image_thumbnail_url': 'https://images.genius.com/75474801ac6b6f258fa0456cccc0147a.300x300x1.png',
#    'header_image_url': 'https://images.genius.com/75474801ac6b6f258fa0456cccc0147a.1000x1000x1.png',
#    'id': 67774,
#    'lyrics_owner_id': 11637,
#    'lyrics_state': 'complete',
#    'path': '/Radiohead-how-to-disappear-completely-lyrics',
#    'primary_artist_names': 'Radiohead',
#    'pyongs_count': 113,
#    'relationships_index_url': 'https://genius.com/Radiohead-how-to-disappear-completely-sample',
#    'release_date_components': {'year': 2000, 'month': 10, 'day': 2},
#    'release_date_for_display': 'October 2, 2000',
#    'release_date_with_abbreviated_month_for_display': 'Oct. 2, 2000',
#    'song_art_image_thumbnail_url': 'https://images.genius.com/75474801ac6b6f258fa0456cccc0147a.300x300x1.png',
#    'song_art_image_url': 'https://images.genius.com/75474801ac6b6f258fa0456cccc0147a.1000x1000x1.png',
#    'stats': {'unreviewed_annotations': 1,
#     'concurrents': 2,
#     'hot': False,
#     'pageviews': 602695},
#    'title': 'How to Disappear Completely',
#    'title_with_featured': 'How to Disappear Completely',
#    'url': 'https://genius.com/Radiohead-how-to-disappear-completely-lyrics',
#    'featured_artists': [],
#    'primary_artist': {'api_path': '/artists/604',
#     'header_image_url': 'https://images.genius.com/808140e9f02c9da6401c0bbb2329a5af.1000x165x1.png',
#     'id': 604,
#     'image_url': 'https://images.genius.com/2642340aee5282c5824397692a49a76a.1000x1000x1.jpg',
#     'is_meme_verified': False,
#     'is_verified': False,
#     'name': 'Radiohead',
#     'url': 'https://genius.com/artists/Radiohead'},
#    'primary_artists': [{'api_path': '/artists/604',
#      'header_image_url': 'https://images.genius.com/808140e9f02c9da6401c0bbb2329a5af.1000x165x1.png',
#      'id': 604,
#      'image_url': 'https://images.genius.com/2642340aee5282c5824397692a49a76a.1000x1000x1.jpg',
#      'is_meme_verified': False,
#      'is_verified': False,
#      'name': 'Radiohead',
#      'url': 'https://genius.com/artists/Radiohead'}]}},
#  {'highlights': [],
#   'index': 'song',
#   'type': 'song',
#   'result': {'annotation_count': 11,
#    'api_path': '/songs/65924',
#    'artist_names': 'Radiohead',
#    'full_title': 'Weird Fishes/Arpeggi by\xa0Radiohead',
#    'header_image_thumbnail_url': 'https://images.genius.com/1253052a5d3475d0c39cc953d72ec261.300x297x1.jpg',
#    'header_image_url': 'https://images.genius.com/1253052a5d3475d0c39cc953d72ec261.599x594x1.jpg',
#    'id': 65924,
#    'lyrics_owner_id': 11637,
#    'lyrics_state': 'complete',
#    'path': '/Radiohead-weird-fishes-arpeggi-lyrics',
#    'primary_artist_names': 'Radiohead',
#    'pyongs_count': 90,
#    'relationships_index_url': 'https://genius.com/Radiohead-weird-fishes-arpeggi-sample',
#    'release_date_components': {'year': 2007, 'month': 10, 'day': 10},
#    'release_date_for_display': 'October 10, 2007',
#    'release_date_with_abbreviated_month_for_display': 'Oct. 10, 2007',
#    'song_art_image_thumbnail_url': 'https://images.genius.com/1253052a5d3475d0c39cc953d72ec261.300x297x1.jpg',
#    'song_art_image_url': 'https://images.genius.com/1253052a5d3475d0c39cc953d72ec261.599x594x1.jpg',
#    'stats': {'unreviewed_annotations': 5, 'hot': False, 'pageviews': 585780},
#    'title': 'Weird Fishes/Arpeggi',
#    'title_with_featured': 'Weird Fishes/Arpeggi',
#    'url': 'https://genius.com/Radiohead-weird-fishes-arpeggi-lyrics',
#    'featured_artists': [],
#    'primary_artist': {'api_path': '/artists/604',
#     'header_image_url': 'https://images.genius.com/808140e9f02c9da6401c0bbb2329a5af.1000x165x1.png',
#     'id': 604,
#     'image_url': 'https://images.genius.com/2642340aee5282c5824397692a49a76a.1000x1000x1.jpg',
#     'is_meme_verified': False,
#     'is_verified': False,
#     'name': 'Radiohead',
#     'url': 'https://genius.com/artists/Radiohead'},
#    'primary_artists': [{'api_path': '/artists/604',
#      'header_image_url': 'https://images.genius.com/808140e9f02c9da6401c0bbb2329a5af.1000x165x1.png',
#      'id': 604,
#      'image_url': 'https://images.genius.com/2642340aee5282c5824397692a49a76a.1000x1000x1.jpg',
#      'is_meme_verified': False,
#      'is_verified': False,
#      'name': 'Radiohead',
#      'url': 'https://genius.com/artists/Radiohead'}]}}]

# %% [markdown]
# ## Exercise 2
#
# Reference the `json_data` in the lab. Notice, when we search for an artist name (e.g., "Missy Elliot") in Genius, the result is a list of *songs* attributed to that artist. Suppose we want to capture information about the artist themselves.
#
# Create a method for our `Genius` class called `.get_artist(search_term)` which does the following:
#
# 1. Extract the (most likely, "Primary") Artist ID from the first "hit" of the `search_term`.
# 2. Use the [API path](https://docs.genius.com/#artists-h2) for this Artist ID to pull information about the artist.
# 3. **Return** the dictionary containing the resulting JSON object.
#
# For example, the following code should return a dictionary of artist information:
#
# ```python
# genius.get_artist("Radiohead")
# ```

# %% [markdown]
# ## Exercise 3
#
# Use the result from Exercise 2 to create another method for our `Genius` class called `.get_artists(search_terms)` (plural) which takes in a *list* of search terms, and returns a DataFrame containing a row for each search term, and the following columns:
#
# - `search_term`: the raw search term from `search_terms`
# - `artist_name`: the (most likely) artist name for the search term
# - `artist_id`: the Genius Artist ID for that artist, based on the API call
# - `followers_count`: the number of followers for that artist (if available)
#
# For example, the following should return a DataFrame with 4 rows:
#
# ```python
# genius.get_artists(['Rihanna', 'Tycho', 'Seal', 'U2'])
# ```

# %% [markdown]
# ## Bonus Exercise (optional)
#
# 1. Gather a list of 100+ various musical artists, and save this list in a TXT file.
# 2. Write a Python *script* that saves the result of `.get_artists` for these artists in a CSV file.
# 3. If you have time, adjust this script to use multiprocessing.
